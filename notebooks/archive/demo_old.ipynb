# %%
from phiesta import connect_insula

client = connect_insula()

features = client.search_l1(date="2026-04-18")
print(len(features), features[0]["properties"]["productIdentifier"])

identifier = features[0]["properties"]["productIdentifier"]

l1 = client.load_l1(identifier)
l1.show_event_info()

l0_folder = client.download_l0(identifier="5095", convert=False)
print(l0_folder)
# Out:
# 15 phisat_PHISAT-2_L1_000005120_20260418183721_20260418183724_1F8D71A7.zip
# [Phiesta] Loading ΦSat-2 L1 from: C:\Users\Malo.DePastor\Phiesta - Light\data\l1\PHISAT-2_L1_000005120_20260418183721_20260418183724_1F8D71A7
# Event: scene_id=0 kind=BC
#   folder: C:\Users\Malo.DePastor\Phiesta - Light\data\l1\PHISAT-2_L1_000005120_20260418183721_20260418183724_1F8D71A7
#   path: C:\Users\Malo.DePastor\Phiesta - Light\data\l1\PHISAT-2_L1_000005120_20260418183721_20260418183724_1F8D71A7\bands\scene_0_BC_multiband.tiff
#   shape: (8, 4096, 4096)   dtype: float32
#   crs: EPSG:4326
#   bounds: None
#   wavelengths_nm: [625, 490, 560, 665, 705, 740, 783, 842]
#   gl_path: C:\Users\Malo.DePastor\Phiesta - Light\data\l1\PHISAT-2_L1_000005120_20260418183721_20260418183724_1F8D71A7\geolocation\GL_scene_0.json
#   processing_config: C:\Users\Malo.DePastor\Phiesta - Light\data\l1\PHISAT-2_L1_000005120_20260418183721_20260418183724_1F8D71A7\processing_config.json
# C:\Users\Malo.DePastor\Phiesta - Light\data\l0\PHISAT-2_L0_000005095_20260417033447_20260417033450_34A2A48C

# %%
l0 = client.load_l0("5095", convert=True)
l0.show_event_info()
# Out:
# === L0_event ===
# Product folder      : C:\Users\Malo.DePastor\Phiesta - Light\data\l0\PHISAT-2_L0_000005095_20260417033447_20260417033450_34A2A48C
# Scene ID            : 0
# Array shape         : (8, 4096, 4096)
# Dtype               : uint16
# Band indices        : [0, 1, 2, 3, 4, 5, 6, 7]
# Band wavelengths nm : [625, 490, 560, 665, 705, 740, 783, 842]
# Band start rows     : [1588, 2140, 1936, 1704, 1152, 932, 716, 1368]
# Line period         : 649
# Native space        : L0_native
# Metadata path       : C:\Users\Malo.DePastor\Phiesta - Light\data\l0\PHISAT-2_L0_000005095_20260417033447_20260417033450_34A2A48C\metadata.json
# Ancillary path      : C:\Users\Malo.DePastor\Phiesta - Light\data\l0\PHISAT-2_L0_000005095_20260417033447_20260417033450_34A2A48C\ancillary.json

# %%
folders = client.download_l1(date="2026-04-10", all_matches=True)
print(len(folders))
print(folders[:3])
# Out:
# 12
# [WindowsPath('C:/Users/Malo.DePastor/Phiesta - Light/data/l1/PHISAT-2_L1_000005144_20260420174251_20260420174254_57EB3EE0'), WindowsPath('C:/Users/Malo.DePastor/Phiesta - Light/data/l1/PHISAT-2_L1_000005143_20260420160930_20260420160933_A335E174'), WindowsPath('C:/Users/Malo.DePastor/Phiesta - Light/data/l1/PHISAT-2_L1_000005142_20260420131519_20260420131522_E41D625F')]

# %% [markdown]
# # Phiesta demo
#
# This first part of the notebook shows how to:
# - connect to Insula,
# - load PHISAT-2 L1 and L0 products,
# - download products by acquisition id or by date,
# - open already available local products.
#
# The first section uses the high-level API.
# A lower-level API is shown later for advanced usage.

# %%
from phiesta import connect_insula

client = connect_insula()

# %% [markdown]
# ## 1. Load one L1 product
#
# Load a PHISAT-2 L1 product by acquisition id.
# The loader first checks local data folders (and optionally VM shared folders), and only downloads from Insula if needed.

# %%
l1 = client.load_l1("5095")
l1.show_event_info()
# Out:
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005095_20260417033447_20260417033450_34A2A48C
# Event: scene_id=0 kind=BC
#   folder: data\l1\PHISAT-2_L1_000005095_20260417033447_20260417033450_34A2A48C
#   path: data\l1\PHISAT-2_L1_000005095_20260417033447_20260417033450_34A2A48C\bands\scene_0_BC_multiband.tiff
#   shape: (8, 4096, 4096)   dtype: float32
#   crs: EPSG:4326
#   bounds: None
#   wavelengths_nm: [625, 490, 560, 665, 705, 740, 783, 842]
#   gl_path: data\l1\PHISAT-2_L1_000005095_20260417033447_20260417033450_34A2A48C\geolocation\GL_scene_0.json
#   processing_config: data\l1\PHISAT-2_L1_000005095_20260417033447_20260417033450_34A2A48C\processing_config.json

# %% [markdown]
# ## 2. Load one L0 product
#
# For L0, the loader can automatically convert `raw.bin` into TIFF band files before opening the event.

# %%
l0 = client.load_l0("5147")
l0.show_event_info()
# Out:
# === L0_event ===
# Product folder      : data\l0\PHISAT-2_L0_000005147_20260421044811_20260421044814_AF2F7C09
# Scene ID            : 0
# Array shape         : (8, 4096, 4096)
# Dtype               : uint16
# Band indices        : [0, 1, 2, 3, 4, 5, 6, 7]
# Band wavelengths nm : [625, 490, 560, 665, 705, 740, 783, 842]
# Band start rows     : [1588, 2140, 1936, 1704, 1152, 932, 716, 1368]
# Line period         : 641
# Native space        : L0_native
# Metadata path       : data\l0\PHISAT-2_L0_000005147_20260421044811_20260421044814_AF2F7C09\metadata.json
# Ancillary path      : data\l0\PHISAT-2_L0_000005147_20260421044811_20260421044814_AF2F7C09\ancillary.json

# %% [markdown]
# ## 3. Download an L0 product without conversion
#
# If needed, you can download the product folder only, without opening it as an event.

# %%
folder = client.download_l0("5095", convert=False)
print(folder)
# Out:
# data\l0\PHISAT-2_L0_000005095_20260417033447_20260417033450_34A2A48C

# %% [markdown]
# ## 4. Search products by date
#
# You can list all products available for a given date.

# %%
features = client.search_l1(date="2026-04-17")
for i, f in enumerate(features):
    p = f["properties"]
    print(i, p["productIdentifier"], p["startDate"])
# Out:
# 0 phisat_PHISAT-2_L1_000005104_20260417190753_20260417190756_E20D19A0.zip 2026-04-17T19:07:53Z
# 1 phisat_PHISAT-2_L1_000005103_20260417173442_20260417173445_4CC709DD.zip 2026-04-17T17:34:42Z
# 2 phisat_PHISAT-2_L1_000005102_20260417160219_20260417160222_1121FB60.zip 2026-04-17T16:02:19Z
# 3 phisat_PHISAT-2_L1_000005101_20260417144006_20260417144009_387BF885.zip 2026-04-17T14:40:06Z
# 4 phisat_PHISAT-2_L1_000005100_20260417124239_20260417124242_507461BA.zip 2026-04-17T12:42:39Z
# 5 phisat_PHISAT-2_L1_000005099_20260417111306_20260417111309_D89BE4A1.zip 2026-04-17T11:13:06Z
# 6 phisat_PHISAT-2_L1_000005098_20260417094414_20260417094417_C9CDC4BE.zip 2026-04-17T09:44:14Z
# 7 phisat_PHISAT-2_L1_000005097_20260417063655_20260417063658_39C8073E.zip 2026-04-17T06:36:55Z
# 8 phisat_PHISAT-2_L1_000005096_20260417050247_20260417050250_5BC74BD8.zip 2026-04-17T05:02:47Z
# 9 phisat_PHISAT-2_L1_000005095_20260417033447_20260417033450_34A2A48C.zip 2026-04-17T03:34:47Z
# 10 phisat_PHISAT-2_L1_000005094_20260417020506_20260417020509_D0D36F1A.zip 2026-04-17T02:05:06Z

# %% [markdown]
# ## 5. Download all L1 products for one day

# %%
folders = client.download_l1(date="2026-04-20", all=True)
# Out:
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005144_20260420174251_20260420174254_57EB3EE0
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005143_20260420160930_20260420160933_A335E174
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005142_20260420131519_20260420131522_E41D625F
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005141_20260420125446_20260420125449_AB4A483E
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005140_20260420112439_20260420112442_F5EDF0CF
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005139_20260420095226_20260420095229_F7293EA1
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005138_20260420082128_20260420082131_592CF36C
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005137_20260420064508_20260420064511_D8AAAC1A
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005136_20260420051543_20260420051546_A3FE07CB
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005135_20260420033546_20260420033549_F551E17E
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005134_20260420020255_20260420020258_CC97C2C1
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005133_20260420004823_20260420004826_DC54EB62

# %% [markdown]
# ## 6. Open products already present locally
#
# Phiesta also supports direct loading from local product folders.

# %%
from pathlib import Path
from phiesta import L0_event, L1_event

l1_path = Path("data/l1/PHISAT-2_L1_000005090_20260416151102_20260416151105_18CCC616")
l0_path = Path("data/l0/PHISAT-2_L0_000005090_20260416151102_20260416151105_18CCC616")

l1_local = L1_event.from_path(str(l1_path))
l0_local = L0_event.from_path(str(l0_path), scene_id=0)

print("L1 local shape:", l1_local.as_numpy().shape)
print("L0 local shape:", l0_local.as_numpy().shape)
# Out:
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005090_20260416151102_20260416151105_18CCC616
# L1 local shape: (8, 4096, 4096)
# L0 local shape: (8, 4096, 4096)

# %% [markdown]
# ## 7. Advanced usage: optional controls

# %%
l0_folder = client.load_l0("5095", convert=False)
print(l0_folder)
# Out:
# data\l0\PHISAT-2_L0_000005095_20260417033447_20260417033450_34A2A48C

# %%
l1 = client.load_l1("5095", force_redownload=True)
# Out:
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005095_20260417033447_20260417033450_34A2A48C

# %%
l1 = client.load_l1("5095", dest_dir="my_custom_data/l1")

# %%
l1 = client.load_l1("5095", vm_fallback=False)
# Out:
# [Phiesta] Loading ΦSat-2 L1 from: data\l1\PHISAT-2_L1_000005095_20260417033447_20260417033450_34A2A48C

# %% [markdown]
# Open and process L0/L1 data

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

from phiesta import (
    L0_event,
    L1_event,
    register_l0_to_l1_space,
    project_bbox_l1_to_l0_native,
)

# %%
# L0 side : integrated plotting helpers
l0.plot_rgb()
l0.plot_rgb(bands=(3, 2, 1))
#l0.plot_all_bands()


# L1 side : RGB via the rgb() method
l1_rgb = l1.rgb()
show_img(l1_rgb, title="L1 RGB", cmap=None)
l0_rgb = l0.rgb()
show_img(l0_rgb, title="L0 RGB", cmap=None)

# %%
ndvi = l1.index("NDVI")
ndwi = l1.index("NDWI")

show_img(ndvi, title="L1 NDVI")
show_img(ndwi, title="L1 NDWI")

# %%
# arbitrary crop to show crop_px
y0, y1, x0, x1 = 500, 1200, 700, 1500

l0_crop = l0.crop_px(y0, y1, x0, x1)
l1_crop = l1.crop_px(y0, y1, x0, x1)

print("L0 crop shape:", l0_crop.as_numpy().shape)
print("L1 crop shape:", l1_crop.as_numpy().shape)

show_img(l0_crop.get_band(7), title="L0 crop - band 7")
show_img(l1_crop.get_band(7), title="L1 crop - band 7")
# Out:
# L0 crop shape: (8, 700, 800)
# L1 crop shape: (8, 700, 800)

# %%
l0_reg = register_l0_to_l1_space(
    l0_event=l0,
    l1_event=l1,
    master_band=7,
    max_shifts=(300, 300),
)

print("L0 registered shape:", l0_reg.as_numpy().shape)

reg_info = l0_reg.get_meta()["registration_info"]
for k, v in reg_info.items():
    print(f"{k}: {v}")
# Out:
# L0 registered shape: (8, 4096, 4096)
# method: phase_correlation_master_then_bands
# master_band: 7
# reference_space: L1_band_7
# master_shift_l0_to_l1_dy_dx: [-1.0, -34.0]
# band_shifts_to_ref_dy_dx: {'0': [0.0, -22.0], '1': [0.0, 14.0], '2': [0.0, 1.0], '3': [-1.0, -11.0], '4': [0.0, -45.0], '5': [-1.0, -58.0], '6': [-1.0, -70.0], '7': [0.0, 0.0]}
# source_l1_path: data\L1\PHISAT-2_L1_000004513_20260126174009_20260126174011_03EAF334\bands\scene_0_BC_multiband.tiff
# l0_original_shape: [8, 4096, 4096]
# l0_registered_shape: [8, 4096, 4096]
# l1_shape: [8, 4096, 4096]
# l0_pre_crop_strategy: none
# l0_top_crop_removed_rows: 0

# %%
ref = l1.get_band(7)

# master band
overlay(ref, l0.get_band(7), title="Before: L1_7 red / L0_7 native green")
overlay(ref, l0_reg.get_band(7), title="After: L1_7 red / L0_7 registered green")

# another band
overlay(ref, l0.get_band(0), title="Before: L1_7 red / L0_0 native green")
overlay(ref, l0_reg.get_band(0), title="After: L1_7 red / L0_0 registered green")

# %%
bbox_l1 = [350, 300, 430, 380]   # [y0, x0, y1, x1]

show_bbox(l1.get_band(7), bbox_l1, title="BBox in L1 band 7")
show_bbox_zoom(l1.get_band(7), bbox_l1, margin=120, title="Zoom on L1 bbox")

# %%
bbox_l0_band7 = project_bbox_l1_to_l0_native(
    bbox_yxyx=bbox_l1,
    registration_info=reg_info,
    target_band=7,
)

bbox_l0_band0 = project_bbox_l1_to_l0_native(
    bbox_yxyx=bbox_l1,
    registration_info=reg_info,
    target_band=0,
)

print("bbox_l1      :", bbox_l1)
print("bbox_l0_b7   :", bbox_l0_band7)
print("bbox_l0_b0   :", bbox_l0_band0)
# Out:
# bbox_l1      : [350, 300, 430, 380]
# bbox_l0_b7   : [351.0, 334.0, 431.0, 414.0]
# bbox_l0_b0   : [350.0, 322.0, 430.0, 402.0]

# %%
show_bbox(l0.get_band(7), bbox_l0_band7, title="Projected bbox in L0 native band 7")
show_bbox_zoom(l0.get_band(7), bbox_l0_band7, margin=120, title="Zoom on projected bbox in L0 native band 7")

show_bbox(l0.get_band(0), bbox_l0_band0, title="Projected bbox in L0 native band 0")
show_bbox_zoom(l0.get_band(0), bbox_l0_band0, margin=120, title="Zoom on projected bbox in L0 native band 0")

# %%
show_bbox_zoom(
    l0.get_band(7),
    bbox_l1,
    margin=120,
    title="Zoom: naive bbox on L0 native band 7"
)

# %%
out_dir = Path("demo_outputs")
out_dir.mkdir(exist_ok=True)

# export of georeferenced L1 crop
l1_crop.export_to_tif(str(out_dir / "demo_l1_crop.tif"))

# export of L0 already registered in the L1 space
l0_reg.export_to_tif(str(out_dir / "demo_l0_in_l1_space.tif"))

# export of a cropped raw L0
l0_crop.export_to_tif(str(out_dir / "demo_l0_crop.tif"))

print("Files written to:", out_dir.resolve())
# Out:
# Files written to: C:\Users\Malo.DePastor\Phiesta - Copy\demo_outputs

# %%
from rasterio.transform import array_bounds, xy

meta = l1.get_meta()

crs = meta["crs"]
transform_aff = meta["transform"]
width = meta["width"]
height = meta["height"]

print("CRS      :", crs)
print("Width    :", width)
print("Height   :", height)
print("Transform:", transform_aff)

west, south, east, north = array_bounds(height, width, transform_aff)

print("\nReconstructed bounds:")
print(f"west  = {west}")
print(f"east  = {east}")
print(f"south = {south}")
print(f"north = {north}")

corners = {
    "top_left": (0, 0),
    "top_right": (0, width - 1),
    "bottom_left": (height - 1, 0),
    "bottom_right": (height - 1, width - 1),
    "center": (height // 2, width // 2),
}

print("\nCoordinates (lat, lon):")
for name, (row, col) in corners.items():
    lon, lat = xy(transform_aff, row, col, offset="center")
    print(f"{name:12s}: lat={lat:.6f}, lon={lon:.6f}")
# Out:
# CRS      : EPSG:4326
# Width    : 4096
# Height   : 4096
# Transform: |-0.00,-0.00,-96.55|
# | 0.00,-0.00, 43.73|
# | 0.00, 0.00, 1.00|
#
# Reconstructed bounds:
# west  = -96.8356186571591
# east  = -96.55272630840787
# south = 43.56211564744168
# north = 43.76749833044427
#
# Coordinates (lat, lon):
# top_left    : lat=43.728179, lon=-96.552761
# top_right   : lat=43.767473, lon=-96.781579
# bottom_left : lat=43.562141, lon=-96.606766
# bottom_right: lat=43.601435, lon=-96.835584
# center      : lat=43.664792, lon=-96.694207

# %%
from rasterio.transform import xy

t = l1.get_meta()["transform"]
H = l1.get_meta()["height"]
W = l1.get_meta()["width"]

row = H // 2
col = W // 2
step = 200

lon_c, lat_c = xy(t, row, col, offset="center")
lon_r, lat_r = xy(t, row, col + step, offset="center")
lon_d, lat_d = xy(t, row + step, col, offset="center")

print("Center:")
print(f"  lat={lat_c:.6f}, lon={lon_c:.6f}")

print("\nWhen moving RIGHT in the image:")
print(f"  dlat = {lat_r - lat_c:.6f}")
print(f"  dlon = {lon_r - lon_c:.6f}")

print("\nWhen moving DOWN in the image:")
print(f"  dlat = {lat_d - lat_c:.6f}")
print(f"  dlon = {lon_d - lon_c:.6f}")
# Out:
# Center:
#   lat=43.664792, lon=-96.694207
#
# When moving RIGHT in the image:
#   dlat = 0.001919
#   dlon = -0.011175
#
# When moving DOWN in the image:
#   dlat = -0.008109
#   dlon = -0.002638

# %%
from rasterio.transform import xy

meta = l1.get_meta()
t = meta["transform"]
H = meta["height"]
W = meta["width"]

pts = {
    "top_left": (0, 0),
    "top_right": (0, W - 1),
    "bottom_left": (H - 1, 0),
    "bottom_right": (H - 1, W - 1),
}

for name, (row, col) in pts.items():
    lon, lat = xy(t, row, col, offset="center")
    print(f"{name:12s}: lat={lat:.6f}, lon={lon:.6f}")
# Out:
# top_left    : lat=43.728179, lon=-96.552761
# top_right   : lat=43.767473, lon=-96.781579
# bottom_left : lat=43.562141, lon=-96.606766
# bottom_right: lat=43.601435, lon=-96.835584

# %%
path = r"C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L2\PHISAT-2_CLOUD_000004451_20260119130559_20260119130602_AAC4DEBC\metadata.json"

with open(path, "r", encoding="utf-8") as f:
    content = f.read()

print(content[-200:])
# Out:
#  {"ExposureTimestamp": 63212136}, "508": {"ExposureTimestamp": 63217440}, "509": {"ExposureTimestamp": 63222744}, "510": {"ExposureTimestamp": 63228048}, "511": {"ExposureTimestamp": 63233352}}}}}}}}}

# %%
#!/usr/bin/env python3


import logging
import shutil
import subprocess
import sys
import time
from pathlib import Path

# -----------------------
# PATHS fissi
# -----------------------
L0_ROOT = Path("C:\\Users\\Malo.DePastor\\Phiesta - Light - Copy\\data\\L0")
SIM_ROOT = Path("C:\\Users\\Malo.DePastor\\Phiesta\\simtotiff\\simtotiff\\SA072-SENSE-Conversion-Code-main\\SA072-SENSE-Conversion-Code-main")
SIMERA_DIR = SIM_ROOT / "simera"  
PACKET_SCRIPT = "packet_to_tiff.py"  
PYTHON_EXE = "python" 

# breve intervallo I/O tra iterazioni
SLEEP_BETWEEN = 0.2

# -----------------------
# Logging
# -----------------------
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[logging.StreamHandler(sys.stdout)]
)

def safe_rmtree(p: Path):
    """Rimuove una cartella ricorsivamente se esiste, logga eventuali errori ma non solleva."""
    try:
        if p.exists():
            logging.info("Rimuovo cartella esistente: %s", p)
            shutil.rmtree(p)
    except Exception as e:
        logging.warning("Errore rimuovendo %s: %s", p, e)

def safe_unlink(f: Path):
    """Rimuove un file se esiste, logga eventuali errori ma non solleva."""
    try:
        if f.exists():
            logging.info("Rimuovo file esistente: %s", f)
            f.unlink()
    except Exception as e:
        logging.warning("Errore rimuovendo file %s: %s", f, e)

def run_packet_to_tiff_blocking(simera_dir: Path):
    """
    Esegue packet_to_tiff.py nella cartella simera_dir SENZA timeout.
    L'output del processo viene mostrato in tempo reale.
    Blocca finché il processo non termina. Restituisce il codice di uscita (int).
    """
    cmd = [PYTHON_EXE, PACKET_SCRIPT]
    logging.info("Eseguo (bloccante): %s in %s", " ".join(cmd), simera_dir)
    try:
        completed = subprocess.run(cmd, cwd=str(simera_dir), check=False)
        logging.info("%s terminato con returncode=%s", PACKET_SCRIPT, completed.returncode)
        return completed.returncode
    except Exception:
        logging.exception("Errore eseguendo %s", PACKET_SCRIPT)
        return 1

def copy_tree_replace(src: Path, dst: Path):
    """Copia src in dst; se dst esiste lo rimuove prima (sovrascrive tutto)."""
    if dst.exists():
        logging.info("Rimuovo esistente %s", dst)
        shutil.rmtree(dst)
    logging.info("Copio %s -> %s", src, dst)
    # shutil.copytree con dirs_exist_ok disponibile su Python>=3.8
    try:
        shutil.copytree(src, dst, dirs_exist_ok=True)
    except TypeError:
        shutil.copytree(src, dst)

def main():
    # sanity checks
    if not L0_ROOT.is_dir():
        logging.error("L0 root non trovato: %s", L0_ROOT)
        sys.exit(1)
    if not SIM_ROOT.is_dir():
        logging.error("SIM_ROOT non trovato: %s", SIM_ROOT)
        sys.exit(1)
    if not SIMERA_DIR.is_dir():
        logging.error("SIMERA_DIR non trovato: %s", SIMERA_DIR)
        sys.exit(1)
    if not (SIMERA_DIR / PACKET_SCRIPT).exists():
        logging.error("Script %s non trovato in %s", PACKET_SCRIPT, SIMERA_DIR)
        sys.exit(1)

    sim_root_raw_folder = SIM_ROOT / "raw"
    sim_root_raw_bin = SIM_ROOT / "raw.bin"

    subdirs = sorted([p for p in L0_ROOT.iterdir() if p.is_dir()])
    logging.info("Trovate %d sottocartelle in %s", len(subdirs), L0_ROOT)

    for i, sub in enumerate(subdirs, start=1):
        logging.info("(%d/%d) Processing %s", i, len(subdirs), sub)
        raw_bin = sub / "raw.bin"
        if not raw_bin.exists():
            logging.info("  -> raw.bin non presente in %s, salto.", sub)
            continue

        # 0) PULIZIA PREVENTIVA in SIM_ROOT
        safe_rmtree(sim_root_raw_folder)
        safe_unlink(sim_root_raw_bin)

        # 1) copia raw.bin in SIM_ROOT (parent della simera)
        try:
            logging.info("  -> Copio %s -> %s", raw_bin, sim_root_raw_bin)
            shutil.copy2(raw_bin, sim_root_raw_bin)
        except Exception as e:
            logging.error("  -> Errore copiando raw.bin: %s", e)
            # assicurati di non lasciare raw.bin parziale
            safe_unlink(sim_root_raw_bin)
            continue

        # 2) esegui packet_to_tiff.py dentro SIMERA_DIR e aspetta la fine
        rc = run_packet_to_tiff_blocking(SIMERA_DIR)

        # 3) se esito != 0 -> logga e pulizia, continua
        if rc != 0:
            logging.error("  -> %s terminato con codice %s: salto copia della cartella raw per %s", PACKET_SCRIPT, rc, sub)
            # pulizia per iterazione successiva
            safe_rmtree(sim_root_raw_folder)
            safe_unlink(sim_root_raw_bin)
            continue

        # 4) processo terminato con successo: verifica che SIM_ROOT/raw esista e contenga file
        if not (sim_root_raw_folder.exists() and any(sim_root_raw_folder.iterdir())):
            logging.error("  -> Dopo esecuzione, %s non esiste o è vuota. Niente da copiare per %s", sim_root_raw_folder, sub)
            # pulizia e continua
            safe_rmtree(sim_root_raw_folder)
            safe_unlink(sim_root_raw_bin)
            continue

        # 5) copia la cartella raw nella sottocartella L0 originale (sovrascrive)
        dest_raw_in_l0 = sub / "raw"
        try:
            copy_tree_replace(sim_root_raw_folder, dest_raw_in_l0)
            logging.info("  -> Copiata cartella raw in %s", dest_raw_in_l0)
        except Exception as e:
            logging.error("  -> Errore copiando raw -> %s: %s", dest_raw_in_l0, e)
            # procedi comunque alla pulizia

        # 6) PULIZIA FINALE: rimuovi SIM_ROOT/raw e SIM_ROOT/raw.bin
        safe_rmtree(sim_root_raw_folder)
        safe_unlink(sim_root_raw_bin)

        # breve pausa I/O
        time.sleep(SLEEP_BETWEEN)

    logging.info("Elaborazione completata.")

if __name__ == "__main__":
    main()
# Out:
# 2026-04-01 23:35:14,680 [INFO] Trovate 107 sottocartelle in C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0
# 2026-04-01 23:35:14,684 [INFO] (1/107) Processing C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004451_20260119130559_20260119130602_AAC4DEBC
# 2026-04-01 23:35:14,689 [INFO]   -> Copio C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004451_20260119130559_20260119130602_AAC4DEBC\raw.bin -> C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw.bin
# 2026-04-01 23:35:14,875 [INFO] Eseguo (bloccante): python packet_to_tiff.py in C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\simera
# 2026-04-01 23:36:40,162 [INFO] packet_to_tiff.py terminato con returncode=0
# 2026-04-01 23:36:40,171 [INFO] Copio C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw -> C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004451_20260119130559_20260119130602_AAC4DEBC\raw
# 2026-04-01 23:36:41,545 [INFO]   -> Copiata cartella raw in C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004451_20260119130559_20260119130602_AAC4DEBC\raw
# 2026-04-01 23:36:41,550 [INFO] Rimuovo cartella esistente: C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw
# 2026-04-01 23:36:41,984 [INFO] (2/107) Processing C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004453_20260119173645_20260119173647_BF99F48F
# 2026-04-01 23:36:41,984 [INFO]   -> Copio C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004453_20260119173645_20260119173647_BF99F48F\raw.bin -> C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw.bin
# 2026-04-01 23:36:42,269 [INFO] Eseguo (bloccante): python packet_to_tiff.py in C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\simera
# 2026-04-01 23:38:44,390 [INFO] packet_to_tiff.py terminato con returncode=0
# 2026-04-01 23:38:44,390 [INFO] Rimuovo esistente C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004453_20260119173645_20260119173647_BF99F48F\raw
# 2026-04-01 23:38:44,520 [INFO] Copio C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw -> C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004453_20260119173645_20260119173647_BF99F48F\raw
# 2026-04-01 23:38:46,032 [INFO]   -> Copiata cartella raw in C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004453_20260119173645_20260119173647_BF99F48F\raw
# 2026-04-01 23:38:46,034 [INFO] Rimuovo cartella esistente: C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw
# 2026-04-01 23:38:46,416 [INFO] (3/107) Processing C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004457_20260121115635_20260121115637_E183F748
# 2026-04-01 23:38:46,420 [INFO]   -> Copio C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004457_20260121115635_20260121115637_E183F748\raw.bin -> C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw.bin
# 2026-04-01 23:38:46,741 [INFO] Eseguo (bloccante): python packet_to_tiff.py in C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\simera
# 2026-04-01 23:40:47,573 [INFO] packet_to_tiff.py terminato con returncode=0
# 2026-04-01 23:40:47,573 [INFO] Rimuovo esistente C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004457_20260121115635_20260121115637_E183F748\raw
# 2026-04-01 23:40:47,600 [INFO] Copio C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw -> C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004457_20260121115635_20260121115637_E183F748\raw
# 2026-04-01 23:40:48,870 [INFO]   -> Copiata cartella raw in C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004457_20260121115635_20260121115637_E183F748\raw
# 2026-04-01 23:40:48,874 [INFO] Rimuovo cartella esistente: C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw
# 2026-04-01 23:40:49,270 [INFO] (4/107) Processing C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004458_20260121121429_20260121121433_EC22582F
# 2026-04-01 23:40:49,270 [INFO]   -> Copio C:\Users\Malo.DePastor\Phiesta - Light - Copy\data\L0\PHISAT-2_L0_000004458_20260121121429_20260121121433_EC22582F\raw.bin -> C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\raw.bin
# 2026-04-01 23:40:49,710 [INFO] Eseguo (bloccante): python packet_to_tiff.py in C:\Users\Malo.DePastor\Phiesta\simtotiff\simtotiff\SA072-SENSE-Conversion-Code-main\SA072-SENSE-Conversion-Code-main\simera
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 158
#     155     logging.info("Elaborazione completata.")
#     157 if __name__ == "__main__":
# --> 158     main()
#
# Cell In[2], line 121, in main()
#     118     continue
#     120 # 2) esegui packet_to_tiff.py dentro SIMERA_DIR e aspetta la fine
# --> 121 rc = run_packet_to_tiff_blocking(SIMERA_DIR)
#     123 # 3) se esito != 0 -> logga e pulizia, continua
#     124 if rc != 0:
#
# Cell In[2], line 59, in run_packet_to_tiff_blocking(simera_dir)
#      57 logging.info("Eseguo (bloccante): %s in %s", " ".join(cmd), simera_dir)
#      58 try:
# ---> 59     completed = subprocess.run(cmd, cwd=str(simera_dir), check=False)
#      60     logging.info("%s terminato con returncode=%s", PACKET_SCRIPT, completed.returncode)
#      61     return completed.returncode
#
# File c:\Users\Malo.DePastor\AppData\Local\Programs\Python\Python310\lib\subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File c:\Users\Malo.DePastor\AppData\Local\Programs\Python\Python310\lib\subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File c:\Users\Malo.DePastor\AppData\Local\Programs\Python\Python310\lib\subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File c:\Users\Malo.DePastor\AppData\Local\Programs\Python\Python310\lib\subprocess.py:1506, in Popen._wait(self, timeout)
#    1503     timeout_millis = int(timeout * 1000)
#    1504 if self.returncode is None:
#    1505     # API note: Returns immediately if timeout_millis == 0.
# -> 1506     result = _winapi.WaitForSingleObject(self._handle,
#    1507                                          timeout_millis)
#    1508     if result == _winapi.WAIT_TIMEOUT:
#    1509         raise TimeoutExpired(self.args, timeout)
#
# KeyboardInterrupt:
